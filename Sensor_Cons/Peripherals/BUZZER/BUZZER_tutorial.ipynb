# %% [markdown]
# # BUZZER — Beginner Tutorial
#
# This tutorial explains how to drive a simple buzzer or piezo with the board using PWM (timer) or GPIO toggling. Includes pin wiring guidance, CubeMX steps to configure a timer PWM channel, example beep code using HAL, and troubleshooting notes.
