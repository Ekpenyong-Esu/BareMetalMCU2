# %% [markdown]
# # FLASH — Beginner Tutorial
#
# This quick guide explains internal/ external flash usage in the project, programming considerations, how to use the flash driver, examples for read/erase/write, and common pitfalls (alignment, sectors, and endurance).
