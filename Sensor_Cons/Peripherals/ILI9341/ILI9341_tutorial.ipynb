# %% [markdown]
# # ILI9341 — Beginner Tutorial
#
# This notebook introduces the ILI9341 SPI display driver in the repo. It covers wiring (SPI pins + DC/CS/RESET), CubeMX & HAL SPI setup, a short API overview, example code to draw text/bitmap, and troubleshooting advice for display initialization issues.
