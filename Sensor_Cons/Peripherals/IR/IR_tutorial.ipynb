# %% [markdown]
# # IR — Beginner Tutorial
#
# This notebook will cover basic IR emitter/receiver usage: hardware wiring, ADC or digital read options, example code for obstacle detection or remote decoding (if an IR receiver module is used), and troubleshooting notes. I'll populate full examples next.
